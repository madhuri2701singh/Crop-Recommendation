# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv(r"C:\Users\omkar\Documents\Crop_recommendation.csv")

# %%
df.head(6)
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# 5  69  37  42    23.058049  83.370118  7.073454  251.055000  rice

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
#last 5 row different object
df.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
#label column access
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
# 'label' column exists in dataset hai
if 'label' in df.columns:
    x=df.drop('label',axis=1)
    y=df['label']

    x.info() #call kareinge
else:
    print("'label' column not found in dataset.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
# dtypes: float64(4), int64(3)
# memory usage: 120.4 KB

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
# dtypes: float64(4), int64(3)
# memory usage: 120.4 KB

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2200 entries, 0 to 2199
# Series name: label
# Non-Null Count  Dtype
# --------------  -----
# 2200 non-null   object
# dtypes: object(1)
# memory usage: 17.3+ KB

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, random_state=1,test_size=0.2)# accuracy change na ho to random state=1 likha

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1650 entries, 91 to 1061
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            1650 non-null   int64
#  1   P            1650 non-null   int64
#  2   K            1650 non-null   int64
#  3   temperature  1650 non-null   float64
#  4   humidity     1650 non-null   float64
#  5   ph           1650 non-null   float64
#  6   rainfall     1650 non-null   float64
# dtypes: float64(4), int64(3)
# memory usage: 103.1 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 550 entries, 1276 to 872
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            550 non-null    int64
#  1   P            550 non-null    int64
#  2   K            550 non-null    int64
#  3   temperature  550 non-null    float64
#  4   humidity     550 non-null    float64
#  5   ph           550 non-null    float64
#  6   rainfall     550 non-null    float64
# dtypes: float64(4), int64(3)
# memory usage: 34.4 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1650 entries, 91 to 1061
# Series name: label
# Non-Null Count  Dtype
# --------------  -----
# 1650 non-null   object
# dtypes: object(1)
# memory usage: 25.8+ KB

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 550 entries, 1276 to 872
# Series name: label
# Non-Null Count  Dtype
# --------------  -----
# 550 non-null    object
# dtypes: object(1)
# memory usage: 8.6+ KB

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#  model create
model = LogisticRegression()

# Train the model
model.fit(x_train, y_train)
# Out:
# C:\Users\omkar\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# test karna)
y_pred1=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
#predictions
y_pred1 = model.predict(x_test)
#calculate accuracy
logistic_reg_acc = accuracy_score(y_test, y_pred1)
print("Logistic Regression accuracy is:", logistic_reg_acc)
# Out:
# Logistic Regression accuracy is: 0.9454545454545454

# %%
model2 = DecisionTreeClassifier()
model2.fit(x_train, y_train)
y_pred3 = model2.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
#predictions for decision tree
y_pred3 = model2.predict(x_test)
#calculate accuracy
decisionc_acc = accuracy_score(y_test, y_pred3)
print("Decision Tree accuracy is: " + str(decisionc_acc))
# Out:
# Decision Tree accuracy is: 0.9840909090909091

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# define random forest
model3 = RandomForestClassifier(n_estimators=100, random_state=42)
#train model
model3.fit(x_train, y_train)
# prediction
y_pred4 = model3.predict(x_test)
# accuracy
random_forest_acc = accuracy_score(y_test, y_pred4)
print("Random Forest accuracy is:", random_forest_acc)
# Out:
# Random Forest accuracy is: 0.9931818181818182

# %%
import joblib

# %%
# define filename
filename = 'crop_app.pkl'

# %%
import joblib 

# inform model2 (DecisionTreeClassifier) is trained before saving
joblib.dump(model2, 'crop_app.pkl')  # Save model

# Load saved model
app = joblib.load('crop_app.pkl')

print("Model saved and loaded successfully!")
# Out:
# Model saved and loaded successfully!

# %%
arr = [[90, 42, 43, 20.879744, 82.002744, 6.502985, 202.935536]]
y_pred5 = app.predict(arr)
# Out:
# C:\Users\omkar\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
print(y_pred5)
# Out:
# ['rice']
